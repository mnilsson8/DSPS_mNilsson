# %% [markdown]
# <a href="https://colab.research.google.com/github/mnilsson8/DSPS_mNilsson/blob/main/Labs/earthquake_data_munging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
earthquakes = pd.read_csv("https://github.com/fedhere/DSPS_FBianco/raw/refs/heads/main/data/earthquakes.csv",sep = r"\s+")

# %%
earthquakes.shape #attribute
# Out:
# (70798, 13)

# %%
earthquakes.head() #method
# Out:
#          date         time   mag
# 0  1984/01/01  01:30:57.52  2.02
# 1  1984/01/01  05:31:34.16  2.12
# 2  1984/01/01  06:59:05.14  2.43
# 3  1984/01/01  11:10:25.29  2.07
# 4  1984/01/01  19:38:19.79  2.13

# %%
earthquakes.tail()
# Out:
#              date         time   mag
# 70793  2002/12/29  19:37:24.56  2.21
# 70794  2002/12/29  20:17:33.40  2.02
# 70795  2002/12/29  20:21:28.73  2.07
# 70796  2002/12/30  21:51:52.55  2.31
# 70797  2002/12/30  23:38:49.79  2.05

# %%
earthquakes.columns
# Out:
# Index(['#YYY/MM/DD', 'HH:mm:SS.ss', 'ET', 'GT', 'MAG', 'M', 'LAT', 'LON',
#        'DEPTH', 'Q', 'EVID', 'NPH', 'NGRM'],
#       dtype='object')

# %%
earthquakes = earthquakes[['#YYY/MM/DD', 'HH:mm:SS.ss','MAG']]

# %%
earthquakes.dtypes
# Out:
# #YYY/MM/DD      object
# HH:mm:SS.ss     object
# MAG            float64
# dtype: object

# %%
earthquakes = earthquakes.rename({"#YYY/MM/DD":"date", "HH:mm:SS.ss":"time", "MAG":"mag"},axis = 1)

# %%
earthquakes.describe()
# Out:
#                 mag
# count  70798.000000
# mean       2.417826
# std        0.407683
# min        2.000000
# 25%        2.120000
# 50%        2.300000
# 75%        2.590000
# max        7.100000

# %%
pd.to_datetime("2002/12/29"+" "+"01:30:57.52")
# Out:
# Timestamp('2002-12-29 01:30:57.520000')

# %%
earthquakes["newdate"] = earthquakes["date"].map(pd.to_datetime)
