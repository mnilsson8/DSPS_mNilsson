# %% [markdown]
# <a href="https://colab.research.google.com/github/mnilsson8/DSPS_mNilsson/blob/main/Labs/trip_times_ztest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
mean_pop = 32.33
threshold = 2

triptimes = pd.read_csv("https://github.com/fedhere/DSPS_FBianco/raw/refs/heads/main/data/triptimes.csv", header = None)
triptimes
# Out:
#             0
# 0   31.622239
# 1   32.821376
# 2   30.229101
# 3   31.413766
# 4   39.010550
# ..        ...
# 95  26.197852
# 96  42.727410
# 97  33.731470
# 98  37.238591
# 99  36.339841
#
# [100 rows x 1 columns]

# %%
mean_time = triptimes[0].mean()
std_time = triptimes[0].std()
n = triptimes.shape[0]
var_time = std_time/np.sqrt(n)

Z = (mean_time-mean_pop)/var_time
print(Z)
if Z > threshold:
  print("Null hypothesis is rejected!")
else:
  print("Null hypothesis is not rejected!")
# Out:
# 2.9929632132528834
# Null hypothesis is rejected!
